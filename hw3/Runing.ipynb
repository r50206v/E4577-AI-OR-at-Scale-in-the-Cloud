# %%
import os
import pandas as pd
from preprocess import *

# %%
stop_words
# Out:
# {'a',
#  'about',
#  'above',
#  'after',
#  'again',
#  'against',
#  'ain',
#  'all',
#  'am',
#  'an',
#  'and',
#  'any',
#  'are',
#  'aren',
#  "aren't",
#  'as',
#  'at',
#  'be',
#  'because',
#  'been',
#  'before',
#  'being',
#  'below',
#  'between',
#  'both',
#  'but',
#  'by',
#  'can',
#  'couldn',
#  "couldn't",
#  'd',
#  'did',
#  'didn',
#  "didn't",
#  'do',
#  'does',
#  'doesn',
#  "doesn't",
#  'doing',
#  'don',
#  "don't",
#  'down',
#  'during',
#  'each',
#  'few',
#  'for',
#  'from',
#  'further',
#  'had',
#  'hadn',
#  "hadn't",
#  'has',
#  'hasn',
#  "hasn't",
#  'have',
#  'haven',
#  "haven't",
#  'having',
#  'he',
#  'her',
#  'here',
#  'hers',
#  'herself',
#  'him',
#  'himself',
#  'his',
#  'how',
#  'i',
#  'if',
#  'in',
#  'into',
#  'is',
#  'isn',
#  "isn't",
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'just',
#  'll',
#  'm',
#  'ma',
#  'me',
#  'mightn',
#  "mightn't",
#  'more',
#  'most',
#  'mustn',
#  "mustn't",
#  'my',
# ...

# %%
path = os.getcwd() + "/glove_twitter/glove.twitter.27B.200d.txt"
embeddingMap = load_embeding(path=path, max_length_dictionary=2000)
len(list(embeddingMap.items()))
# Out:
# 2000

# %%
embeddingMap
# Out:
# {'rt': 0,
#  'i': 1,
#  'a': 2,
#  'the': 3,
#  'you': 4,
#  'to': 5,
#  'me': 6,
#  'de': 7,
#  'que': 8,
#  'and': 9,
#  'my': 10,
#  'no': 11,
#  'is': 12,
#  'it': 13,
#  'in': 14,
#  'n': 15,
#  'for': 16,
#  'of': 17,
#  'la': 18,
#  'do': 19,
#  'that': 20,
#  'on': 21,
#  'y': 22,
#  'e': 23,
#  'o': 24,
#  'u': 25,
#  'en': 26,
#  'this': 27,
#  'el': 28,
#  'so': 29,
#  'be': 30,
#  'with': 31,
#  'just': 32,
#  'your': 33,
#  'like': 34,
#  'have': 35,
#  'te': 36,
#  'at': 37,
#  'love': 38,
#  'se': 39,
#  'are': 40,
#  'm': 41,
#  'r': 42,
#  'if': 43,
#  'all': 44,
#  'b': 45,
#  'not': 46,
#  'but': 47,
#  'we': 48,
#  'es': 49,
#  'ya': 50,
#  'follow': 51,
#  'up': 52,
#  'what': 53,
#  'get': 54,
#  'lol': 55,
#  'un': 56,
#  'lo': 57,
#  'when': 58,
#  'was': 59,
#  'one': 60,
#  'por': 61,
#  'si': 62,
#  'out': 63,
#  'mi': 64,
#  'can': 65,
#  'من': 66,
#  'he': 67,
#  'con': 68,
#  'they': 69,
#  'now': 70,
#  'go': 71,
#  'para': 72,
#  'los': 73,
# ...

# %%
df = pd.read_csv(os.getcwd() + '/eng_twitter.csv')
df['text'].apply(
    lambda x: replace_token_with_index(
        tokenize_text(clean_text(x), tokenizer=tknzr, stop_words=stop_words), 
        embeddingMap
    )
).values.tolist()
# Out:
# [[],
#  [218, 82, 459],
#  [260, 602, 301, 520],
#  [1460, 721, 525],
#  [1587],
#  [1608, 443, 493, 443, 781],
#  [325, 222, 484],
#  [347, 1907],
#  [241],
#  [509, 886],
#  [1558, 605, 34, 338],
#  [162, 150, 60, 270, 1274],
#  [1614, 760, 772, 521, 1057],
#  [335, 927, 71, 529, 529],
#  [1445, 1285],
#  [149],
#  [100],
#  [866],
#  [1433, 71, 80, 711],
#  [],
#  [586, 240, 173, 249],
#  [905],
#  [],
#  [39, 1555, 371, 185],
#  [509, 992],
#  [1284, 1082, 102],
#  [],
#  [],
#  [285, 906, 842, 302],
#  [],
#  [1208],
#  [1264],
#  [819, 241, 149],
#  [],
#  [132, 639, 227, 322, 1670, 1431],
#  [1831, 34],
#  [],
#  [470, 483, 758, 346, 946],
#  [249, 239, 300],
#  [1578, 146, 816],
#  [1908],
#  [],
#  [],
#  [],
#  [],
#  [135, 889, 253, 253],
#  [388, 1893, 1555],
#  [42, 1099, 579, 458, 132, 25],
#  [167, 781],
#  [167],
#  [],
#  [946, 608, 483],
#  [1867, 1297, 209],
#  [],
#  [54],
#  [221, 500],
#  [],
#  [],
#  [150, 324, 92],
#  [1109, 521, 332, 387, 131, 274, 565],
# ...
